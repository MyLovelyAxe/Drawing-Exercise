# %% [markdown]
# #### How to create a .exe file
# <fond size = 2>
#
# 1.Type in command line：
#
#     pyinstaller -F "D:\Hard Li\Python\Drawing_Exercise_Set\ljx_pic\9pic_patch.py"
#
# Attention:
#
#     -F means only generate one executable file;
#     The path must contain 'space' or it goes error;
#     The path should be surrounded by double quotation marks "";
#
#
# 2.Add the full name of the executable file, including .exe;
#
# 3.Find the location of generated file on the second last line:
#
#     Appending archive to EXE C:\Users\asus\dist\Drawing_Exercise_Template.exe
#
# 4.Double click to start it.
#
# Attention:
#
#     Only .py file can succeed. Download .ipynb as .py firstly.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import os

# %%
pic_folder_path = 'd:/Hard Li/Python/Drawing_Exercise_Set/ljx_pic'
pic_folder_lst = os.listdir(pic_folder_path)
print(pic_folder_lst)
# Out:
# ['9pic_patch.py', 'Diluc', 'Jean', 'Kaeya', 'Lisa', 'Razor', 'traveler']

# %%
wanted = input('which pic do you want to patch?')
wanted_path = pic_folder_path + '/' + wanted
wanted_part_lst = os.listdir(wanted_path)
print(wanted_part_lst)
# Out:
# which pic do you want to patch?Razor
# ['1.jpg', '2.jpg', '3.jpg', '4.jpg', '5.jpg', '6.jpg', '7.jpg', '8.jpg', '9.jpg']

# %%
sample_pic = mpimg.imread(wanted_path + '/' + wanted_part_lst[0])
H,W,C = sample_pic.shape
print(H,W,C)
# Out:
# 750 750 3
# F:\Anaconda\lib\site-packages\PIL\TiffImagePlugin.py:793: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))

# %%
pic_lst = []
for i in wanted_part_lst:
    pic_part = mpimg.imread(wanted_path + '/' + i)
    pic_lst.append(pic_part)
print(len(pic_lst))
# Out:
# 9

# %%
pic_whole = np.zeros([H * 3,W * 3,C])
print(pic_whole.shape)
# Out:
# (2250, 2250, 3)

# %%
for col in range(3):
    for row in range(3):
        pic_whole[col*W:(col+1)*W,row*H:(row+1)*H,:] = pic_lst[row+col*3]
#imshow need the input data be in range of [0,1]
#but the original pictures are usually of [0,255]
#so normalize the input date by 255 will solve the issue
#if only want to show the picture instead of save it as well
#call  ''.astype('uint8')'' will help
pic_whole = pic_whole/255
plt.imshow(pic_whole)

# %%
mpimg.imsave(wanted_path + '/whole.jpg', arr = pic_whole)
